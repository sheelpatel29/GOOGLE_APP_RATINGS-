# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
df=pd.read_csv("App_Ratings_cleaned.csv")

# %%
df.Price.unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
#Performing uniVariate analysis 

df.boxplot(column=["Price"],figsize=(12,6))

# %%
df.boxplot(column=["Reviews"],figsize=(12,6))

# %%
df.Installs.quantile([0.1,0.25,0.50,0.75,0.95,0.99])
# Out:
# 0.10         1000.0
# 0.25        10000.0
# 0.50       500000.0
# 0.75      5000000.0
# 0.95    100000000.0
# 0.99    500000000.0
# Name: Installs, dtype: float64

# %%
df.hist(column=["Rating"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000165CCB4FF48>]],
#       dtype=object)

# %%
df.hist(column=["Size"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000165CCBB81C8>]],
#       dtype=object)

# %%
#Note: We can see there are outliers in Price and Reviews, which are to be treated

# %%
df[df["Price"]>200]
# Out:
#       Unnamed: 0                             App   Category  Rating  Reviews  \
# 4037        4197          most expensive app (H)     FAMILY     4.3      6.0
# 4190        4362                      💎 I'm rich  LIFESTYLE     3.8    718.0
# 4195        4367        I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0
# 5044        5351                       I am rich  LIFESTYLE     3.8   3547.0
# 5047        5354                  I am Rich Plus     FAMILY     4.0    856.0
# 5048        5355                   I am rich VIP  LIFESTYLE     3.8    411.0
# 5049        5356               I Am Rich Premium    FINANCE     4.1   1867.0
# 5050        5357             I am extremely Rich  LIFESTYLE     2.9     41.0
# 5051        5358                      I am Rich!    FINANCE     3.8     93.0
# 5052        5359              I am rich(premium)    FINANCE     3.5    472.0
# 5055        5362                   I Am Rich Pro     FAMILY     4.4    201.0
# ...

# %%
#This seems that apps with greater than 200$ is unwanted and mostly suspicious apps, so drop it

# %%
df1=df[df["Price"]<200].copy()

# %%
df1
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9354       10834                                      FR Calculator
# 9355       10836                                   Sya9a Maroc - FR
# 9356       10837                   Fr. Mike Schmitz Audio Teachings
# 9357       10839                      The SCP Foundation DB fr nn5n
# 9358       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating   Reviews     Size    Installs  Type  Price  \
# ...

# %%
#Also reviews greater than 2Million are mostly star apps, which is not useful for analysis, so drop them for accuracy

# %%
df=df1[df1["Reviews"]<2*1e7]
df
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 9354       10834                                      FR Calculator
# 9355       10836                                   Sya9a Maroc - FR
# 9356       10837                   Fr. Mike Schmitz Audio Teachings
# 9357       10839                      The SCP Foundation DB fr nn5n
# 9358       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating   Reviews     Size    Installs  Type  Price  \
# ...

# %%
df=df[df["Installs"]< 5000000.0].copy()
df
# Out:
#       Unnamed: 0                                             App  \
# 0              0  Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                             Coloring book moana
# 4              4           Pixel Draw - Number Art Coloring Book
# 5              5                      Paper flowers instructions
# 6              6         Smoke Effect Photo Maker - Smoke Editor
# ...          ...                                             ...
# 9353       10833                                     Chemin (fr)
# 9354       10834                                   FR Calculator
# 9355       10836                                Sya9a Maroc - FR
# 9356       10837                Fr. Mike Schmitz Audio Teachings
# 9357       10839                   The SCP Foundation DB fr nn5n
#
#                  Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0          ART_AND_DESIGN     4.1    159.0  19000.0   10000.0  Free    0.0
# ...

# %%
plt.figure(figsize=(12.8,6),dpi=80)
plt.scatter(df["Rating"],df["Price"])
plt.xlabel("Ratings")
plt.ylabel("Price")
plt.title("Ratings V/S Price Analysis")
# Out:
# Text(0.5, 1.0, 'Ratings V/S Price Analysis')

# %%
#Ratings increase with increase in Price

# %%
plt.figure(figsize=(12.8,6),dpi=80)
plt.scatter(df["Rating"],df["Size"])
plt.xlabel("Ratings")
plt.ylabel("Size")
plt.title("Ratings V/S Size Analysis")
# Out:
# Text(0.5, 1.0, 'Ratings V/S Size Analysis')

# %%
#Larger Size app are rated better

# %%
plt.figure(figsize=(12.8,6),dpi=80)
plt.scatter(df["Rating"],df["Reviews"])
plt.xlabel("Ratings")
plt.ylabel("Reviews")
plt.title("Ratings V/S Reviews Analysis")
# Out:
# Text(0.5, 1.0, 'Ratings V/S Reviews Analysis')

# %%
#It is clearly evident that reviews go higher with ratings in mind

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6512 entries, 0 to 9357
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      6512 non-null   int64
#  1   App             6512 non-null   object
#  2   Category        6512 non-null   object
#  3   Rating          6512 non-null   float64
#  4   Reviews         6512 non-null   float64
#  5   Size            5960 non-null   float64
#  6   Installs        6512 non-null   float64
#  7   Type            6512 non-null   object
#  8   Price           6512 non-null   float64
#  9   Content Rating  6512 non-null   object
#  10  Genres          6512 non-null   object
#  11  Last Updated    6512 non-null   object
#  12  Current Ver     6508 non-null   object
#  13  Android Ver     6510 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 763.1+ KB

# %%
df=df.rename({'Content Rating':'Content_Rating'},axis=1)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="Content_Rating", y="Rating", data=df,palette="colorblind",hue='Content_Rating')

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x="Rating", y="Category",data=df)

# %%
#performing model development

# %%
df["Reviews"].skew()
# Out:
# 5.52602526609633

# %%
df['log_Reviews']= np.log1p(df["Reviews"])

# %%
df['log_Reviews'].skew()
# Out:
# -0.1246569509895223

# %%
ax=sns.distplot(df["log_Reviews"])

# %%
df['log_Installs']= np.log1p(df["Installs"])

# %%
ax=sns.distplot(df["log_Installs"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6512 entries, 0 to 9357
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      6512 non-null   int64
#  1   App             6512 non-null   object
#  2   Category        6512 non-null   object
#  3   Rating          6512 non-null   float64
#  4   Reviews         6512 non-null   float64
#  5   Size            5960 non-null   float64
#  6   Installs        6512 non-null   float64
#  7   Type            6512 non-null   object
#  8   Price           6512 non-null   float64
#  9   Content_Rating  6512 non-null   object
#  10  Genres          6512 non-null   object
#  11  Last Updated    6512 non-null   object
#  12  Current Ver     6508 non-null   object
#  13  Android Ver     6510 non-null   object
#  14  log_Reviews     6512 non-null   float64
#  15  log_Installs    6512 non-null   float64
# dtypes: float64(7), int64(1), object(8)
# ...

# %%
df1=df.drop(columns={"Current Ver","Android Ver"},axis=1,inplace=True)

# %%
df1 = pd.get_dummies(df, columns=['Category','Genres','Content_Rating'])

# %%
df1=df1.dropna()

# %%
df1.to_csv("df_preprocess")
